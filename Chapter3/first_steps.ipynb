# %%
import numpy as np
file_data_path='DATA/sample.xyz'
point_cloud= np.loadtxt(file_data_path, skiprows=1, max_rows=1000000)

# %%
point_cloud[1]
# Out:
# array([ 1.07206253, -0.7416798 , -5.10408789, 14.        , 12.        ,
#        17.        ])

# %%
point_cloud[1][3]
# Out:
# 14.0

# %%
point_cloud[:,1]
# Out:
# array([-4.75981225, -0.7416798 , -1.76128496, ...,  2.83534847,
#         2.48451363,  4.16210495])

# %%
point_cloud[:,:3]
# Out:
# array([[ 2.75421051, -4.75981225, -6.44403559],
#        [ 1.07206253, -0.7416798 , -5.10408789],
#        [-2.84094568, -1.76128496, -6.89372498],
#        ...,
#        [-3.56255241,  2.83534847, -7.39112478],
#        [-4.51143929,  2.48451363, -4.1180287 ],
#        [-5.5110726 ,  4.16210495, -7.6481533 ]])

# %%
xyz = point_cloud[:,:3]
rgb = point_cloud[:,3:]

np.mean(point_cloud,axis=0)[2]
# Out:
# -5.914919177226882

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

file_data_path="DATA/sample.xyz"
point_cloud= np.loadtxt(file_data_path,skiprows=1)

mean_Z = np.mean(point_cloud,axis=0)[2]
spatial_query = point_cloud[abs( point_cloud[:,2]-mean_Z)<1]

xyz=spatial_query[:,:3]
rgb=spatial_query[:,3:]

ax = plt.axes(projection='3d')

ax.scatter(xyz[:,0],xyz[:,1],xyz[:,2], c=rgb/255, s=0.05)
plt.show()
